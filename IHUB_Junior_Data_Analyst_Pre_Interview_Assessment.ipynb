# %% [markdown]
# <a href="https://colab.research.google.com/github/mithamokelvinm/Ameili/blob/master/IHUB_Junior_Data_Analyst_Pre_Interview_Assessment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Some priors to avoid restarting and rerunning the notebook over and over
# !pip uninstall -y numpy
# !pip install numpy==1.23.5 --force-reinstall --no-cache-dir
# !pip install --force-reinstall --no-cache-dir gensim
# Out:
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 226.6 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.23.5 which is incompatible.
# jax 0.5.2 requires numpy>=1.25, but you have numpy 1.23.5 which is incompatible.
# xarray 2025.3.1 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.
# treescope 0.1.9 requires numpy>=1.25.2, but you have numpy 1.23.5 which is incompatible.
# bigframes 2.1.0 requires numpy>=1.24.0, but you have numpy 1.23.5 which is incompatible.
# bigframes 2.1.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# ...

# %% [markdown]
# # IHUB Junior Data Analyst Pre Interview Assessment

# %% [markdown]
# ## Section 1: Critical Thinking, Research and Analytical Skills Testing
# As a data analyst supporting the research team in curating data and insights to back up their research on civic technology, please perform the following task;

# %% [markdown]
# ## Highlight the steps you will take to curate credible secondary datasets that support the research work.
#
# ### Step 1: Define Research Objectives
#
# First, before conducting research, it is necessary to clarify the specific focus of the research for example, civic engagement, e-voting, or even digital governance.
#
# Secondly, one needs to identify the population or region of interest for the research, for example, African countries, urban vs rural populations.
#
# ### Step 2: Identify Reliable Data Sources To Prioritize
# Use only credible data sources. Depending on the research you are carrying out, they could vary from:
#
# - Government Portals - Example, data.gov
#
# - Research Institutions - Example, World Bank, UNDP, OECD
#
# - Civic Tech Platforms - Example mySociety, GovLab, Open Knowledge Foundation
#
# - Academic Databases - Example, Google Scholar, JSTOR
#
# - Open Source Communities - Example, GitHub, Kaggle datasets
#
# ### Step 3: Evaluate Data Credibility
# To evaluate data credibility, one could use criteria like checking:
#
# - Source reputation and authority of the dataset's owner / orgarnization
#
# - Transparency of methodology used to create the dataset
#
# - Timeliness and frequency of updates of the dataset
#
# - Licensing of the dataset although I prefer open/public datasets.

# %% [markdown]
# ## Extract the data from the identified sources

# %%
# Extracting data from identified data sources depends with the data source

# Example: Load CSV data from a civic tech dataset
# df = pd.read_csv("...")

# Loading data from excel
# df = pd.read_excel("...")

# Loading data from json
# df = pd.read_json("...")

# Loading data from apis
# import requests
# url = "https://api.opencivicdata.org/v1/bills/"
# response = requests.get(url)
# data = response.json()
# df = pd.json_normalize(data['results'])

# Loading data from a Mongo Database
# from pymongo import MongoClient

# Local MongoDB
# client = MongoClient(host="localhost", port=27017)

# Select database and collection
# db = client["your_database_name"]
# collection = db["your_collection_name"]

# %% [markdown]
# ## Clean and prepare the data for analysis

# %% [markdown]
# To clean and prepare data, one needs to handle miising values, standardize column names, and convert date/time fields if they are not in the needed formarts.
#
# When working with machine learning models, encoding categorical variables is also a handy data cleaning and preparation technique.

# %% [markdown]
# ## Analyse the data, drawing actionable insights

# %% [markdown]
# To analyze the data and drawing actionable insights one needs to descriptive and inferential statistical methods as well as visualization methods to present the insights.
#
# To explore patterns data visualization tools like seaborn, plotly, and matplotlib come in handy too.
#
# For A/B testing one can apply hypothesis testing (t-tests, chi-square, ANOVA) to assess associations or group differences.
#
# More so, one can use clustering and keyword analysis (NLP) for open-ended responses to identify emerging themes.

# %% [markdown]
# ## Document all the insights in a shareable Word document, slides or PDF

# %% [markdown]
# After doing the analysis, one need to prepare the insights and share them in formats tailored to the audience.
#
# Some of the ways one can do this include sharing word documents or PDFs using python-docx or Jupyter export for detailed reports.
#
# Slide decks too using python-pptx are excellent for executive summaries and stakeholder presentations.
#
# Making sure that each insight is explained with supporting visuals and backed by evidence is crucial.

# %% [markdown]
# # Section 2: Statistical Skills Testing Using a sample dataset for talent_survey , perform the following tasks:

# %% [markdown]
# 1. Generate descriptive statistics for the demographic characteristics of the respondents.
# 2. Identify the most common programming languages that students were exposed to
# during their coursework.
# 3. Use an appropriate statistical method to test whether the average number of required
# industrial training sessions is equal to 2.
# 4. Apply a suitable inferential statistics method to draw conclusions about student
# satisfaction with the quality of lectures received.
# Where 1 = Very dissatisfied, 2 = Dissatisfied, 3 = Indifferent, 4 = Satisfied, 5 = Very
# satisfied
# 5. Use the chi-square method to analyze students' perceptions of whether the course
# design meets the current needs of the tech industry.
# where 1=strongly disagree, 2=disagree, 3=indifferent, 4=agree, and 5=strongly agree
# Please share the code used to conduct the analysis above.

# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from scipy import stats
from scipy.stats import ttest_1samp, chisquare
import seaborn as sns

# %%
# Connect to Google Drive for remote access
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import the `talent_survey` dataset
talent_df = pd.read_csv('/content/drive/MyDrive/ihub_files/talent_survey - talent_survey.csv')

# %%
# Overview of the `talent_survey` dataset
talent_df.head()
# Out:
#                               Token          Submitted At Respondent gender  \
# 0  3iecc17hcyssjxsvos923iecc17fg2zb  2023-01-26T09:33:23Z              Male
# 1  79cmx9f35a8rkpzg5yyvz79cmlq1b7ma  2023-02-09T20:43:25Z              Male
# 2  guvgwczzamuzfti9rguv2g2j7qso42c0  2023-01-10T18:32:38Z              Male
# 3  9d6kacm78oea59bd9dyglv2ykut38xku  2023-01-26T18:00:00Z              Male
# 4  rjnc2lqphru2g0nt3bvtirjnc97xevrr  2023-01-23T17:39:49Z              Male
#
#   Age Group Institution category  \
# 0  20 to 24           University
# 1  20 to 24          Polytechnic
# 2  20 to 24           University
# 3  20 to 24           University
# 4  20 to 24           University
#
#    Please rate your satisfaction with the quality of the lectures you receive  \
# 0                                                  4
# 1                                                  4
# 2                                                  3
# 3                                                  3
# ...

# %%
# Exploratory Data Anaysis (Columns, Non-Null Counts and Dtypes)
talent_df.info()

# Dataset Shape
print("Dataset Shape: ",talent_df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 9 columns):
#  #   Column                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                   --------------  -----
#  0   Token                                                                                    250 non-null    object
#  1   Submitted At                                                                             250 non-null    object
#  2   Respondent gender                                                                        250 non-null    object
#  3   Age Group                                                                                250 non-null    object
#  4   Institution category                                                                     250 non-null    object
# ...

# %%
# Rename column names
talent_df = talent_df.rename(columns={
    "Submitted At": "submitted_at",
    "Respondent gender": "gender",
    "Age Group": "age_group",
    "Institution category": "institution_category",
    "Please rate your satisfaction with the quality of the lectures you receive": "lecture_satisfaction",
    "I think the course is designed in a way that meets the current tech industry needs": "course_relevance",
    "How many separate industrial trainings are you expected to complete in your department?": "industrial_training_sessions",
    "What programming languages were you exposed to in the school curriculum?": "programming_languages"
})
talent_df.head()
# Out:
#                               Token          submitted_at gender age_group  \
# 0  3iecc17hcyssjxsvos923iecc17fg2zb  2023-01-26T09:33:23Z   Male  20 to 24
# 1  79cmx9f35a8rkpzg5yyvz79cmlq1b7ma  2023-02-09T20:43:25Z   Male  20 to 24
# 2  guvgwczzamuzfti9rguv2g2j7qso42c0  2023-01-10T18:32:38Z   Male  20 to 24
# 3  9d6kacm78oea59bd9dyglv2ykut38xku  2023-01-26T18:00:00Z   Male  20 to 24
# 4  rjnc2lqphru2g0nt3bvtirjnc97xevrr  2023-01-23T17:39:49Z   Male  20 to 24
#
#   institution_category  lecture_satisfaction  course_relevance  \
# 0           University                     4               NaN
# 1          Polytechnic                     4               2.0
# 2           University                     3               2.0
# 3           University                     3               NaN
# 4           University                     1               1.0
#
#    industrial_training_sessions  \
# 0                           NaN
# 1                           2.0
# ...

# %% [markdown]
# ## Generate descriptive statistics for the demographic characteristics of the respondents.

# %%
# Age counts per `Age Group`
age_counts = talent_df['age_group'].value_counts().reset_index(name="Count")
age_counts
# Out:
#       age_group  Count
# 0      20 to 24    182
# 1      Below 20     36
# 2      25 to 29     30
# 3  30 and above      2

# %%
# Create a percentage-based age distribution bar chart
fig = px.bar(
    talent_df['age_group']
        .value_counts(normalize=True)
        .mul(100)
        .round(1)
        .reset_index(name='Percentage'),
    x='Percentage',
    y='age_group',
    orientation='h',
    title='Talent Survey Respondents by Age Group (%)',
    text='Percentage',
    color='age_group'
)

fig.update_layout(
    xaxis_title="Percentage (%)",
    yaxis_title="Age Group",
    showlegend=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Gender counts per `Respondent gender`
gender_counts = talent_df["gender"].value_counts()
gender_counts
# Out:
# gender
# Male      142
# Female    108
# Name: count, dtype: int64

# %%
# Create a percentage-based gender distribution bar chart
fig = px.bar(
    talent_df['gender']
        .value_counts(normalize=True)
        .mul(100)
        .round(1)
        .reset_index(name='Percentage'),
    x='gender',
    y='Percentage',
    title='Talent Survey Respondents by Institution (%)',
    text='Percentage',
    color='gender'
)

fig.update_layout(
    yaxis_title="Percentage (%)",
    xaxis_title="Gender",
    showlegend=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Institution counts by `institution category`
institution_counts = talent_df["institution_category"].value_counts().reset_index(name="Count")
institution_counts
# Out:
#    institution_category  Count
# 0            University    192
# 1           Polytechnic     44
# 2  College of Education     14

# %%
# Create a percentage-based institution distribution bar chart
fig = px.bar(
    talent_df['institution_category']
        .value_counts(normalize=True)
        .mul(100)
        .round(1)
        .reset_index(name='Percentage'),
    x='institution_category',
    y='Percentage',
    title='Talent Survey Respondents by Institution Category (%)',
    text='Percentage',
    color='institution_category'
)

fig.update_layout(
    yaxis_title="Percentage (%)",
    xaxis_title="Institution Category",
    showlegend=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Identify the most common programming languages that students were exposed to during their coursework.

# %%
# Drop missing values
lang_series = talent_df['programming_languages'].dropna()

# Split and flatten the list
all_langs = lang_series.str.split(',').explode().str.strip()

# Count occurrences
language_counts = all_langs.value_counts().reset_index()

# Display top 10 languages
language_counts.head(10)
# Out:
#   programming_languages  count
# 0                   C++     56
# 1                Python     54
# 2                  Java     48
# 3                 BASIC     47
# 4            JavaScript     34
# 5               FORTRAN     30
# 6                     C     28
# 7                    C#     28
# 8                   SQL     26
# 9          Visual Basic     17

# %%
# Bar chart of most common programming languages
fig = px.bar(
    language_counts.head(10),  # Top 10 languages
    x='count',
    y='programming_languages',
    orientation='h',
    title='Top 10 Programming Languages Exposed to During Coursework',
    color='programming_languages'
)

fig.update_layout(xaxis_title='Number of Mentions', yaxis_title='Programming Language')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Use an appropriate statistical method to test whether the average number of required industrial training sessions is equal to 2.

# %%
# Drop missing values from the column
training_sessions = talent_df['industrial_training_sessions'].dropna()

# One-sample t-test
t_stat, p_value = stats.ttest_1samp(training_sessions, popmean=2)

print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The average number of trainings is significantly different from 2.")
else:
    print("Fail to reject the null hypothesis: No significant difference from 2.")
# Out:
# T-statistic: -4.7874
# P-value: 0.0000
# Reject the null hypothesis: The average number of trainings is significantly different from 2.

# %% [markdown]
# ## Apply a suitable inferential statistics method to draw conclusions about student satisfaction with the quality of lectures received. Where 1 = Very dissatisfied, 2 = Dissatisfied, 3 = Indifferent, 4 = Satisfied, 5 = Very satisfied

# %%
# Drop NaN values
satisfaction_scores = talent_df["lecture_satisfaction"].dropna()

# Run one-sample t-test against the neutral score of 3
t_stat, p_value = ttest_1samp(satisfaction_scores, popmean=3)

print(f"Mean satisfaction score: {satisfaction_scores.mean():.2f}")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("✅ Conclusion: There is a statistically significant difference from neutral satisfaction.")
else:
    print("ℹ️ Conclusion: No significant difference from neutral satisfaction.")
# Out:
# Mean satisfaction score: 3.06
# T-statistic: 0.8302
# P-value: 0.4072
# ℹ️ Conclusion: No significant difference from neutral satisfaction.

# %% [markdown]
# ## Use the chi-square method to analyze students' perceptions of whether the course design meets the current needs of the tech industry.where 1=strongly disagree, 2=disagree, 3=indifferent, 4=agree, and 5=strongly agree

# %%
# Drop NaN values from the relevant column
course_perception = talent_df["course_relevance"].dropna()

# Get observed frequencies
observed_freq = course_perception.value_counts().sort_index()

# Expected frequencies under uniform distribution
expected_freq = [len(course_perception) / 5] * 5  # since we expect uniformity across 5 categories

# Run Chi-square test
chi2_stat, p_value = chisquare(f_obs=observed_freq, f_exp=expected_freq)

print("Observed Frequencies:\n", observed_freq)
print(f"\nChi-square Statistic: {chi2_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("✅ Conclusion: The distribution is not uniform — students show significant perceptions.")
else:
    print("ℹ️ Conclusion: No significant difference from a uniform perception — responses are evenly distributed.")
# Out:
# Observed Frequencies:
#  course_relevance
# 1.0    35
# 2.0    34
# 3.0    60
# 4.0    43
# 5.0    12
# Name: count, dtype: int64
#
# Chi-square Statistic: 32.6848
# P-value: 0.0000
# ✅ Conclusion: The distribution is not uniform — students show significant perceptions.

# %%
# Plot the actual distribution of responses
response_dist = course_perception.value_counts(normalize=True).sort_index() * 100

fig = px.bar(x=response_dist.index,
             y=response_dist.values,
             labels={'x': 'Perception (1=Strongly Disagree → 5=Strongly Agree)', 'y': 'Percentage'},
             title='Student Perception of Course Design Relevance')
fig.update_layout(yaxis_title="Percentage", xaxis_title="Response Scale (1-5)")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Section 3: Emerging Technologies Skills Testing
# ## Using the text_data attached, perform the following tasks:

# %% [markdown]
# ## Define entity recognition
# Entity Recognition also called NER (Named Entity Recognition) is a Natural Language Processing (NLP) technique that locates and classifies named entities in text into predefined categories such as:
#
# - Geographical Locations (example, “Nairobi”)
#
# - Organizations (example, “World Health Organization”)
#
# - People (example, “Bill Gates”)
#
# - Dates (example, “January 2023”)
#
# - Amounts (example, “$10 million”)
#
# NER is essential for extracting structured information from unstructured text.

# %% [markdown]
# ## Based on your understanding of the concept of entity recognition, extract the following information from the text: geographical locations, organizations, people, dates, and amounts mentioned in the text. Present the results graphically.

# %%
# Load our text_data to a df
text_df = pd.read_csv("/content/drive/MyDrive/ihub_files/text_data - text_data.csv")
text_df.head()
# Out:
#          date                                              title  \
# 0  2023-10-05  As its workers strike, Kaiser Permanente strik...
# 1  2022-11-11            Sight Tech Global 2022 agenda announced
# 2  2023-07-12  UK femtech Daye launches virtual clinic for pe...
# 3  2024-05-02  Peloton to lay off 400 employees as CEO Barry ...
# 4  2024-01-09  Smart ring maker Ultrahuman announces tracker ...
#
#            category                                              story
# 0  Biotech & Health  Yesterday, 75,000 workers at healthcare giant ...
# 1  Biotech & Health  The third annual Sight Tech Global conference,...
# 2  Biotech & Health  U.K. women’s health Daye has a new string to i...
# 3  Biotech & Health  Peloton, the exercise equipment maker and onli...
# 4           Gadgets  Indian wearable startup Ultrahuman is getting ...

# %%
# Numpy fix
# !pip install --force-reinstall numpy==1.23.5
# !pip install --force-reinstall spacy

# %%
# Imports needed for this section
import spacy
from collections import Counter

# %%
# Load spaCy language model
nlp = spacy.load("en_core_web_sm")

# Store all named entities in a list
all_entities = []

# Loop through each column in the DataFrame
for column in text_df.columns:
    if text_df[column].dtype == 'object':  # Only process text columns
        text = " ".join(text_df[column].dropna().astype(str))
        doc = nlp(text)

        # Use doc.ents to access named entities, not tokens
        entities = [(ent.text, ent.label_, column)
                    for ent in doc.ents
                    if ent.label_ in ['GPE', 'ORG', 'PERSON', 'DATE', 'MONEY']]
        all_entities.extend(entities)

# Convert to DataFrame for further analysis or visualization
entity_df = pd.DataFrame(all_entities, columns=["Entity", "Label", "Source_Column"])
entity_df.head()
# Out:
#                              Entity Label Source_Column
# 0  2023-10-05 2022-11-11 2023-07-12  DATE          date
# 1                        2024-05-02  DATE          date
# 2             2024-01-09 2023-05-24  DATE          date
# 3             2024-01-09 2023-06-20  DATE          date
# 4             2024-02-20 2023-10-12  DATE          date

# %%
# Visualize entity distribution
plt.figure(figsize=(10, 6))
sns.countplot(data=entity_df, x="Label", order=entity_df["Label"].value_counts().index)
plt.title("Named Entity Distribution Across All Columns")
plt.xlabel("Entity Type")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## Perform topic modelling on the text to identify key thematic areas that the authors discuss in the article.

# %%
# Prior installation of gensim - Rerun everytime you restart the session
# !pip install numpy==1.23.5
# Numpy fix
# !pip install --force-reinstall --no-cache-dir gensim

# %%
# Imports needed for this section
from gensim import corpora, models
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import nltk

# %%
# Download NLTK resources
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Combine all text columns into one list of documents
all_text = text_df.select_dtypes(include='object').fillna('').astype(str)
documents = all_text.apply(lambda row: ' '.join(row.values), axis=1)

# Preprocessing
stop_words = set(stopwords.words('english'))
tokens = [word_tokenize(doc.lower()) for doc in documents]
tokens = [[word for word in doc if word.isalpha() and word not in stop_words] for doc in tokens]

# Dictionary and Corpus
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(text) for text in tokens]

# Train LDA model
lda_model = models.LdaModel(corpus, num_topics=5, id2word=dictionary, passes=10, random_state=42)

# Print topics
for i, topic in lda_model.print_topics():
    print(f"Topic {i + 1}: {topic}")
# Out:
# Topic 1: 0.006*"also" + 0.005*"company" + 0.005*"health" + 0.005*"startup" + 0.004*"new" + 0.004*"device" + 0.004*"like" + 0.004*"said" + 0.004*"use" + 0.004*"product"
# Topic 2: 0.008*"ai" + 0.005*"health" + 0.005*"also" + 0.005*"new" + 0.004*"one" + 0.004*"like" + 0.004*"company" + 0.004*"data" + 0.004*"said" + 0.003*"tech"
# Topic 3: 0.011*"health" + 0.007*"said" + 0.007*"healthcare" + 0.007*"care" + 0.006*"million" + 0.006*"ai" + 0.005*"also" + 0.005*"startup" + 0.005*"platform" + 0.004*"medical"
# Topic 4: 0.008*"health" + 0.008*"company" + 0.006*"new" + 0.005*"said" + 0.005*"also" + 0.005*"million" + 0.004*"like" + 0.004*"proteins" + 0.004*"protein" + 0.004*"data"
# Topic 5: 0.013*"health" + 0.008*"company" + 0.007*"said" + 0.007*"million" + 0.005*"also" + 0.005*"startup" + 0.005*"new" + 0.004*"healthcare" + 0.004*"ai" + 0.004*"like"

# %% [markdown]
# ## Using transformer models, summarize the text into one precise paragraph.

# %%
# # Numpy fix
# !pip uninstall -y numpy
# !pip install numpy==1.23.5 --force-reinstall --no-cache-dir

# %%
# Make sure you change from cpu to gpu
from transformers import pipeline

# Initialize summarization pipeline
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")

# Text columns
text_columns =  ["title", "category", "story"]

# Concatenate all text entries across selected columns into one large string
all_texts = []
for col in text_columns:
    all_texts.extend(text_df[col].dropna().astype(str).tolist())

full_text = " ".join(all_texts)

# Break into smaller chunks due to model input size limits (~1024 tokens)
max_len = 1000  # slightly lower than 1024 tokens to stay safe
text_chunks = [full_text[i:i+max_len] for i in range(0, len(full_text), max_len)]

# Generate summaries
summaries = [summarizer(chunk, max_length=130, min_length=30, do_sample=False)[0]['summary_text'] for chunk in text_chunks]

# Join summaries into a final paragraph
final_summary = " ".join(summaries)

print("Summary:\n", final_summary)
# Out:
# Device set to use cuda:0
# Summary:
# ...

# %% [markdown]
# ## Apply unsupervised machine learning techniques to classify the texts into the following categories, generating ratios for each class.
# Categories: Advanced Gene Editing, mRNA Technology, CAR-T Cell Therapy, Organoids and Tissue Engineering, Single-Cell Genomics, Synthetic Biology, Biological Computing, Wearable Biosensors, Microbiome Therapeutics, Nanomedicine

# %%
# Text Preprocessing
import re

# Clean and combine all text columns
text_columns = text_df.select_dtypes(include='object').columns
text_df['combined_text'] = text_df[text_columns].fillna('').agg(' '.join, axis=1)

# Clean up the text
def clean_text(text):
    text = re.sub(r'\W+', ' ', text)
    return text.lower()

text_df['clean_text'] = text_df['combined_text'].apply(clean_text)
documents = text_df['clean_text'].tolist()

# %%
# Sentence Embedding with Transformers
# !pip install -q sentence-transformers
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('all-MiniLM-L6-v2')  # One can also use a biomedical one like 'pritamdeka/BioBERT-mnli-snli-scinli-scitail-mednli-stsb'
document_embeddings = model.encode(documents, show_progress_bar=True)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 67.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 35.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 43.3 MB/s eta 0:00:00
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# ...

# %%
# Embed Category Definitions
categories = [
    "Advanced Gene Editing", "mRNA Technology", "CAR-T Cell Therapy",
    "Organoids and Tissue Engineering", "Single-Cell Genomics",
    "Synthetic Biology", "Biological Computing", "Wearable Biosensors",
    "Microbiome Therapeutics", "Nanomedicine"
]

category_embeddings = model.encode(categories)

# %%
# Classify Each Document by Nearest Category (Cosine Similarity
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Compute similarities and classify
similarity_matrix = cosine_similarity(document_embeddings, category_embeddings)
predicted_indices = np.argmax(similarity_matrix, axis=1)
predicted_labels = [categories[i] for i in predicted_indices]
text_df['predicted_category'] = predicted_labels

# %%
# Generate Category Ratios
category_counts = text_df['predicted_category'].value_counts(normalize=True) * 100
print(category_counts.round(2))
# Out:
# predicted_category
# Nanomedicine                        26.00
# Biological Computing                20.00
# mRNA Technology                     19.33
# Wearable Biosensors                 10.67
# Synthetic Biology                   10.00
# Microbiome Therapeutics              4.67
# Advanced Gene Editing                3.33
# Organoids and Tissue Engineering     2.67
# CAR-T Cell Therapy                   2.67
# Single-Cell Genomics                 0.67
# Name: proportion, dtype: float64

# %% [markdown]
# ## Extract and explain emerging trends within the industry

# %% [markdown]
# Based on analysis of text data, the following emerging trends highlight areas with strong innovation potential and startup opportunities that align with iHub’s mission to support transformative technologies:
#
# - Nanomedicine is redefining drug delivery through nanoscale technologies. Startups in this space can focus on diagnostics, precision drug targeting, and AI-enabled molecular simulations—fields ripe for VC and research grant funding.
#
# - Biological Computing is an avant-garde domain with potential for startups developing DNA-based processors or synthetic biology toolkits. It requires investment in computational biology talent and partnerships with research institutions.
#
# - mRNA Technology, beyond COVID-19 vaccines, is expanding into cancer, - genetic diseases, and personalized medicine. Startups can create platforms for mRNA drug discovery, rapid prototyping, or delivery systems—highly fundable and scalable ideas.
#
# - Wearable Biosensors offer real-time health monitoring and are ideal for health-tech startups focused on chronic disease management, sports performance, and elder care. These solutions are hardware/software hybrids, making them attractive for both health and IoT innovation streams.
#
# - Synthetic Biology enables startups to engineer organisms for sustainable food, biomaterials, and climate solutions. This intersects with biotech, agri-tech, and climate-tech—all key thematic areas for socially-driven innovation funding.
#
# - Microbiome Therapeutics represents a growing field with opportunities in personalized nutrition, probiotics, and gut health diagnostics. Startups can leverage data platforms to create tailored microbiome-based products.
#
# - Advanced Gene Editing tools like CRISPR open doors for startups creating diagnostics, therapeutics, or gene-editing platforms. Regulatory complexity remains, but impact and investment potential are high.
#
# - Organoids and Tissue Engineering can power startups building models for drug testing, reducing animal testing, or advancing regenerative medicine. Innovations here can attract partnerships from pharma and biotech corporations.
#
# - CAR-T Cell Therapy is a niche but high-impact space where startups can innovate around automation, cell engineering platforms, or data infrastructure to support clinical trials.
#
# - Single-Cell Genomics empowers startups to uncover new drug targets, disease markers, and patient stratification tools. It’s a data-intensive space ideal for machine learning–driven biotech ventures.

# %% [markdown]
# ## Draw conclusions.

# %% [markdown]
# As an innovation hub that supports and funds transformative startups, iHub stands at a pivotal moment to harness the momentum of emerging biotech and health-tech trends. The analysis of industry signals reveals clear areas where startup innovation, guided by data science, can generate both social impact and commercial success. Below are key takeaways that highlight how iHub can align its strategy to support the next generation of breakthrough ventures:
#
# 1. Strategic Opportunity for Startup Development -
# Each identified trend represents a significant white space for startup creation—particularly in biotechnology, digital health, and deep tech. By cultivating ventures in these areas, iHub can position itself as a regional leader and global launchpad for next-gen companies that fuse data science with biology and engineering.
#
# 2. Data Science is the Innovation Lever -
# The common denominator across all trends is the heavy reliance on data—ranging from genomics and biosensor data to biological simulations. Startups that embed machine learning, bioinformatics, and predictive modeling into their solutions will be best positioned to deliver value and secure funding.
#
# 3. Cross-Disciplinary Collaboration is Key -
# Innovation in these fields demands collaboration across biology, computing, and engineering. iHub can strengthen its ecosystem by encouraging interdisciplinary teams, co-founder matchmaking, and access to domain-specific mentors who bridge science and entrepreneurship.
#
# 4. Scalability and Global Relevance -
# These trends are not only locally impactful but also globally significant. Startups incubated at iHub have the potential to tackle African healthcare challenges while remaining competitive in international markets—such as biotech supply chains, drug development, and digital diagnostics.
#
# 5. Readiness for Funding and Acceleration -
# Global investors and innovation funds are actively seeking startups in areas like personalized medicine, synthetic biology, and digital therapeutics. iHub can increase the success rate of its portfolio by aligning its funding calls, accelerator themes, and pitch support toward these high-growth, fundable domains.
